# %% [markdown]
# # CNN to classify images

# %% [markdown]
# ## Import libaries

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# to hide warnings or atleast some of them (caused by mapping with lambda)
# the warnings are not present in colab
import logging
logging.getLogger("tensorflow").disabled = True

# %% [markdown]
# ## Load dataset

# %%
(train_image, train_label), (test_image, test_label) = tf.keras.datasets.cifar10.load_data()

# %% [markdown]
# ## Inspect the dataset

# %%
# Declare which number(index) corresponds to which class
classes = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]

n = 5
fig, ax = plt.subplots(1, n, figsize=(10,10))
for index, [image, label] in enumerate(zip(train_image[0:n], train_label[0:n])):
    ax[index].imshow(image)
    ax[index].set_title(classes[label[0]])
    ax[index].axis('off')

# %% [markdown]
# ## Preprocess the data

# %%
# combine images and labels into a tf dataset
train_image = tf.data.Dataset.from_tensor_slices(train_image)
train_label = tf.data.Dataset.from_tensor_slices(train_label)
test_image = tf.data.Dataset.from_tensor_slices(test_image)
test_label = tf.data.Dataset.from_tensor_slices(test_label)

train_dataset = tf.data.Dataset.zip((train_image, train_label))
test_dataset = tf.data.Dataset.zip((test_image, test_label))                                                
                                                
                                                
# create minibatches
train_dataset = train_dataset.batch(64)
test_dataset = test_dataset.batch(64)

# normalize images and encode labels onehot
train_dataset = train_dataset.map(lambda image, label: 
                                         (2*(image/255)-1, tf.squeeze(tf.one_hot(label, 10))), 
                                  num_parallel_calls=tf.data.experimental.AUTOTUNE).cache()

test_dataset = test_dataset.map(lambda image, label: 
                                          (2*(image/255)-1,  tf.squeeze(tf.one_hot(label, 10))), 
                                  num_parallel_calls=tf.data.experimental.AUTOTUNE).cache()

# shuffle data
train_dataset = train_dataset.shuffle(64)
test_dataset = test_dataset.shuffle(64)

# Prefetch
train_dataset = train_dataset.prefetch(tf.data.experimental.AUTOTUNE)
test_dataset = test_dataset.prefetch(tf.data.experimental.AUTOTUNE)

# %% [markdown]
# ## Define the model

# %%
from tensorflow.keras import Model

class Model(Model): 
    
    def __init__(self):
        super(Model, self).__init__()
        self.convolutional_layer_1 = tf.keras.layers.Conv2D(
            filters=256,
            kernel_size=5,
            strides=1,
            padding='same',
            activation='relu',
            #kernel_regularizer=tf.keras.regularizers.l2(0.01),
            input_shape= (32, 32, 3))
        
        self.dropout_1 = tf.keras.layers.Dropout(rate = 0.5)
        
        self.max_pool_1 = tf.keras.layers.MaxPool2D()

        self.convolutional_layer_2 = tf.keras.layers.Conv2D(
            filters=128,
            kernel_size=3,
            padding='same',
            activation='relu',
            #kernel_regularizer=tf.keras.regularizers.l2(0.01)
            )
        
        self.dropout_2 = tf.keras.layers.Dropout(rate = 0.5)
        
        self.max_pool_2 = tf.keras.layers.MaxPool2D()

        self.convolutional_layer_3 = tf.keras.layers.Conv2D(
            filters=256,
            kernel_size=3,
            padding='same',
            activation='relu',
            #kernel_regularizer=tf.keras.regularizers.l2(0.01)
            )
        
        self.dropout_3 = tf.keras.layers.Dropout(rate = 0.5)
        
        self.max_pool_3 = tf.keras.layers.MaxPool2D()

        self.convolutional_layer_4 = tf.keras.layers.Conv2D(
            filters=256,
            kernel_size=2,
            padding='same',
            activation='relu',
            #kernel_regularizer=tf.keras.regularizers.l2(0.01)
            )
        
        self.dropout_4 = tf.keras.layers.Dropout(rate = 0.5)
        
        self.max_pool_4 = tf.keras.layers.MaxPool2D()
        
        self.global_average_pooling_layer = tf.keras.layers.GlobalAvgPool2D()

        self.hidden_layer_1 = tf.keras.layers.Dense(
            units=100,
            activation='sigmoid')
        
        self.dropout_5 = tf.keras.layers.Dropout(rate = 0.5)
        
        self.hidden_layer_2 = tf.keras.layers.Dense(
            units=100,
            activation='sigmoid')
        
        self.dropout_6 = tf.keras.layers.Dropout(rate = 0.5)

        self.output_layer = tf.keras.layers.Dense(
            units=10,
            activation='softmax')

    def call(self, x, training = True):
        x = self.convolutional_layer_1(x)
        x = self.dropout_1(x, training)
        x = self.max_pool_1(x)
        x = self.convolutional_layer_2(x)
        x = self.dropout_2(x, training)
        x = self.max_pool_2(x)
        x = self.convolutional_layer_3(x)
        x = self.dropout_3(x, training)
        x = self.max_pool_3(x)
        x = self.convolutional_layer_4(x)
        x = self.dropout_4(x, training)
        x = self.max_pool_4(x)
        x = self.global_average_pooling_layer(x)
        x = self.hidden_layer_1(x)
        x = self.dropout_5(x)
        x = self.hidden_layer_2(x)
        x = self.dropout_6(x)
        x = self.output_layer(x)
        return x

# %% [markdown]
# ## Define traning and testing

# %%
def train_step(model, input, target, loss_function, optimizer, training = True):
    with tf.GradientTape() as tape:
        prediction = model(input, training)
        loss = loss_function(target, prediction) #+ tf.reduce_sum(model.losses)
        accuracy = np.mean(np.argmax(target, axis = 1) == np.argmax(prediction, axis = 1))
        gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    return loss, accuracy

def test(model, test_data, loss_function, training = False):
    # Test over complete test data

    test_accuracy_aggregator = []
    test_loss_aggregator = []

    for (input, target) in test_data:
        prediction = model(input, training)
        sample_test_loss = loss_function(target, prediction)
        sample_test_accuracy =  np.mean(np.argmax(target, axis = 1) == np.argmax(prediction, axis = 1))
        test_loss_aggregator.append(sample_test_loss.numpy())
        test_accuracy_aggregator.append(sample_test_accuracy)

    test_loss = np.mean(test_loss_aggregator)
    test_accuracy = np.mean(test_accuracy_aggregator)

    return test_loss, test_accuracy

# %% [markdown]
# ## Train the model

# %%
# %%time
tf.keras.backend.clear_session()

### Hyperparameters
num_epochs = 140
learning_rate = 0.0001
running_average_factor = 0.95

model = Model()

# Initialize the loss
cross_entropy_loss = tf.keras.losses.CategoricalCrossentropy()

# Initialize the optimizer
optimizer = tf.keras.optimizers.Adam(learning_rate)

# Initialize lists for later visualization.
train_losses = []
train_accuracies = []

test_losses = []
test_accuracies = []

# Testing model performance on train and test data before learning
train_loss, train_accuracy = test(model, train_dataset, cross_entropy_loss)
train_losses.append(train_loss)
train_accuracies.append(train_accuracy)

test_loss, test_accuracy = test(model, test_dataset, cross_entropy_loss)
test_losses.append(test_loss)
test_accuracies.append(test_accuracy)

# Train loop for num_epochs epochs.
for epoch in range(num_epochs):
    print('Epoch: __ ' + str(epoch))

    train_dataset = train_dataset.shuffle(buffer_size=64)
    test_dataset = test_dataset.shuffle(buffer_size=64)

    # Training
    running_average_loss = 0
    running_average_accuracy = 0
    for (input,target) in train_dataset:
        train_loss, train_accuracy = train_step(model, input, target, cross_entropy_loss, optimizer)
        running_average_loss = running_average_factor * running_average_loss  + (1 - running_average_factor) * train_loss
        running_average_accuracy = running_average_factor * running_average_accuracy  + (1 - running_average_factor) * train_accuracy
        
        
    train_losses.append(running_average_loss)
    train_accuracies.append(running_average_accuracy)

    # Testing
    test_loss, test_accuracy = test(model, test_dataset, cross_entropy_loss)
    print('Train loss: ',running_average_loss)
    print('Test loss: ',test_loss)
    print('Train accuracy: ',running_average_accuracy)
    print('Test accuracy: ',test_accuracy, "\n")
    test_losses.append(test_loss)
    test_accuracies.append(test_accuracy)
# Out:
# Epoch: __ 0
# Train loss:  tf.Tensor(2.0794618, shape=(), dtype=float32)
# Test loss:  2.0396607
# Train accuracy:  0.20579015565052533
# Test accuracy:  0.26054936305732485
#
# Epoch: __ 1
# Train loss:  tf.Tensor(1.9560199, shape=(), dtype=float32)
# Test loss:  1.9350376
# Train accuracy:  0.2542603360303188
# Test accuracy:  0.32593550955414013
#
# Epoch: __ 2
# Train loss:  tf.Tensor(1.8015254, shape=(), dtype=float32)
# Test loss:  1.8647255
# Train accuracy:  0.3025957863154758
# Test accuracy:  0.3783837579617834
#
# Epoch: __ 3
# Train loss:  tf.Tensor(1.7001508, shape=(), dtype=float32)
# Test loss:  1.7770821
# Train accuracy:  0.3482458296018211
# Test accuracy:  0.38057324840764334
#
# Epoch: __ 4
# Train loss:  tf.Tensor(1.621828, shape=(), dtype=float32)
# Test loss:  1.7002629
# Train accuracy:  0.3843686390400201
# Test accuracy:  0.45222929936305734
#
# Epoch: __ 5
# Train loss:  tf.Tensor(1.5401634, shape=(), dtype=float32)
# Test loss:  1.64406
# Train accuracy:  0.419009659104056
# Test accuracy:  0.46865047770700635
#
# Epoch: __ 6
# Train loss:  tf.Tensor(1.4205192, shape=(), dtype=float32)
# Test loss:  1.5866512
# Train accuracy:  0.4840031464416549
# Test accuracy:  0.5078622611464968
#
# Epoch: __ 7
# Train loss:  tf.Tensor(1.442485, shape=(), dtype=float32)
# Test loss:  1.5240258
# Train accuracy:  0.46709954326757125
# Test accuracy:  0.5232882165605095
#
# Epoch: __ 8
# Train loss:  tf.Tensor(1.3394333, shape=(), dtype=float32)
# Test loss:  1.4841148
# Train accuracy:  0.515282523924225
# Test accuracy:  0.5420979299363057
#
# Epoch: __ 9
# Train loss:  tf.Tensor(1.3212082, shape=(), dtype=float32)
# Test loss:  1.4512575
# Train accuracy:  0.5191100682884315
# Test accuracy:  0.5309514331210191
#
# Epoch: __ 10
# Train loss:  tf.Tensor(1.2172544, shape=(), dtype=float32)
# Test loss:  1.4257694
# Train accuracy:  0.5696092053605009
# Test accuracy:  0.5544386942675159
#
# Epoch: __ 11
# Train loss:  tf.Tensor(1.2231455, shape=(), dtype=float32)
# Test loss:  1.4182305
# Train accuracy:  0.5664632283149251
# Test accuracy:  0.5576234076433121
#
# Epoch: __ 12
# Train loss:  tf.Tensor(1.2052222, shape=(), dtype=float32)
# Test loss:  1.4065229
# Train accuracy:  0.5636884154037861
# Test accuracy:  0.5590167197452229
#
# Epoch: __ 13
# Train loss:  tf.Tensor(1.1437398, shape=(), dtype=float32)
# Test loss:  1.3468039
# Train accuracy:  0.6011376576903227
# Test accuracy:  0.598328025477707
#
# Epoch: __ 14
# Train loss:  tf.Tensor(1.1325283, shape=(), dtype=float32)
# Test loss:  1.375023
# Train accuracy:  0.5978359681535509
# Test accuracy:  0.5566281847133758
#
# Epoch: __ 15
# Train loss:  tf.Tensor(1.0862868, shape=(), dtype=float32)
# Test loss:  1.2993724
# Train accuracy:  0.6295960002004534
# Test accuracy:  0.6180334394904459
#
# Epoch: __ 16
# Train loss:  tf.Tensor(1.0177401, shape=(), dtype=float32)
# Test loss:  1.2974308
# Train accuracy:  0.6479854706764009
# Test accuracy:  0.6031050955414012
#
# Epoch: __ 17
# Train loss:  tf.Tensor(1.05264, shape=(), dtype=float32)
# Test loss:  1.2940243
# Train accuracy:  0.6344780304529534
# Test accuracy:  0.5798168789808917
#
# Epoch: __ 18
# Train loss:  tf.Tensor(1.037405, shape=(), dtype=float32)
# Test loss:  1.237641
# Train accuracy:  0.6413417424214534
# Test accuracy:  0.6098726114649682
#
# Epoch: __ 19
# Train loss:  tf.Tensor(0.983151, shape=(), dtype=float32)
# Test loss:  1.1999761
# Train accuracy:  0.6659372156293576
# Test accuracy:  0.6455015923566879
#
# Epoch: __ 20
# Train loss:  tf.Tensor(1.0150477, shape=(), dtype=float32)
# Test loss:  1.1687934
# Train accuracy:  0.660350021578395
# Test accuracy:  0.6649084394904459
#
# Epoch: __ 21
# Train loss:  tf.Tensor(0.95230407, shape=(), dtype=float32)
# Test loss:  1.2007227
# Train accuracy:  0.6706775410449944
# Test accuracy:  0.6170382165605095
#
# Epoch: __ 22
# Train loss:  tf.Tensor(0.92432773, shape=(), dtype=float32)
# Test loss:  1.1414912
# Train accuracy:  0.695417465077405
# Test accuracy:  0.6700835987261147
#
# Epoch: __ 23
# Train loss:  tf.Tensor(0.8632954, shape=(), dtype=float32)
# Test loss:  1.0968999
# Train accuracy:  0.7114310164095999
# Test accuracy:  0.682921974522293
#
# Epoch: __ 24
# Train loss:  tf.Tensor(0.9024265, shape=(), dtype=float32)
# Test loss:  1.1276826
# Train accuracy:  0.6893392709810208
# Test accuracy:  0.669984076433121
#
# Epoch: __ 25
# Train loss:  tf.Tensor(0.8855129, shape=(), dtype=float32)
# Test loss:  1.0895573
# Train accuracy:  0.6964030943835939
# Test accuracy:  0.6840167197452229
#
# Epoch: __ 26
# Train loss:  tf.Tensor(0.8688129, shape=(), dtype=float32)
# Test loss:  1.1043079
# Train accuracy:  0.704905083946089
# Test accuracy:  0.6585390127388535
#
# Epoch: __ 27
# Train loss:  tf.Tensor(0.846103, shape=(), dtype=float32)
# Test loss:  1.0934299
# Train accuracy:  0.7046149735639239
# Test accuracy:  0.6748606687898089
#
# Epoch: __ 28
# Train loss:  tf.Tensor(0.80493426, shape=(), dtype=float32)
# Test loss:  1.0900626
# Train accuracy:  0.7200388899867621
# Test accuracy:  0.6734673566878981
#
# Epoch: __ 29
# Train loss:  tf.Tensor(0.78615516, shape=(), dtype=float32)
# Test loss:  1.0947287
# Train accuracy:  0.7345885914905079
# Test accuracy:  0.6854100318471338
#
# Epoch: __ 30
# Train loss:  tf.Tensor(0.74213696, shape=(), dtype=float32)
# Test loss:  1.0699978
# Train accuracy:  0.7542211277354384
# Test accuracy:  0.6843152866242038
#
# Epoch: __ 31
# Train loss:  tf.Tensor(0.79187405, shape=(), dtype=float32)
# Test loss:  1.0440292
# Train accuracy:  0.7273128319531482
# Test accuracy:  0.6877985668789809
#
# Epoch: __ 32
# Train loss:  tf.Tensor(0.7900593, shape=(), dtype=float32)
# Test loss:  1.0354861
# Train accuracy:  0.7287752619731616
# Test accuracy:  0.7052149681528662
#
# Epoch: __ 33
# Train loss:  tf.Tensor(0.7494593, shape=(), dtype=float32)
# Test loss:  0.998422
# Train accuracy:  0.7459648966828605
# Test accuracy:  0.7202428343949044
#
# Epoch: __ 34
# Train loss:  tf.Tensor(0.7135987, shape=(), dtype=float32)
# Test loss:  0.9909874
# Train accuracy:  0.7581757574038429
# Test accuracy:  0.7106886942675159
#
# Epoch: __ 35
# Train loss:  tf.Tensor(0.7042971, shape=(), dtype=float32)
# Test loss:  0.9991384
# Train accuracy:  0.7601713987192733
# Test accuracy:  0.7174562101910829
#
# Epoch: __ 36
# Train loss:  tf.Tensor(0.69763845, shape=(), dtype=float32)
# Test loss:  0.9849635
# Train accuracy:  0.7619755371872078
# Test accuracy:  0.7121815286624203
#
# Epoch: __ 37
# Train loss:  tf.Tensor(0.718677, shape=(), dtype=float32)
# Test loss:  0.96892077
# Train accuracy:  0.7566092308412556
# Test accuracy:  0.7308917197452229
#
# Epoch: __ 38
# Train loss:  tf.Tensor(0.69952756, shape=(), dtype=float32)
# Test loss:  0.95465505
# Train accuracy:  0.7627125136325424
# Test accuracy:  0.7388535031847133
#
# Epoch: __ 39
# Train loss:  tf.Tensor(0.6679439, shape=(), dtype=float32)
# Test loss:  0.95923144
# Train accuracy:  0.7753904461858275
# Test accuracy:  0.7385549363057324
#
# Epoch: __ 40
# Train loss:  tf.Tensor(0.6705976, shape=(), dtype=float32)
# Test loss:  0.96381956
# Train accuracy:  0.7780246141787147
# Test accuracy:  0.7388535031847133
#
# Epoch: __ 41
# Train loss:  tf.Tensor(0.67208314, shape=(), dtype=float32)
# Test loss:  0.9610856
# Train accuracy:  0.7760745936419036
# Test accuracy:  0.7383558917197452
#
# Epoch: __ 42
# Train loss:  tf.Tensor(0.6869002, shape=(), dtype=float32)
# Test loss:  0.9391523
# Train accuracy:  0.7685660860296686
# Test accuracy:  0.7469148089171974
#
# Epoch: __ 43
# Train loss:  tf.Tensor(0.65091157, shape=(), dtype=float32)
# Test loss:  0.9490745
# Train accuracy:  0.7722314554220906
# Test accuracy:  0.7398487261146497
#
# Epoch: __ 44
# Train loss:  tf.Tensor(0.6170203, shape=(), dtype=float32)
# Test loss:  0.9059631
# Train accuracy:  0.7946125636844359
# Test accuracy:  0.7648288216560509
#
# Epoch: __ 45
# Train loss:  tf.Tensor(0.63404757, shape=(), dtype=float32)
# Test loss:  0.92035234
# Train accuracy:  0.7869885038487041
# Test accuracy:  0.7488057324840764
#
# Epoch: __ 46
# Train loss:  tf.Tensor(0.6248426, shape=(), dtype=float32)
# Test loss:  0.9309877
# Train accuracy:  0.7865208811858059
# Test accuracy:  0.7455214968152867
#
# Epoch: __ 47
# Train loss:  tf.Tensor(0.6004286, shape=(), dtype=float32)
# Test loss:  0.88942295
# Train accuracy:  0.7988287541809407
# Test accuracy:  0.7625398089171974
#
# Epoch: __ 48
# Train loss:  tf.Tensor(0.6449938, shape=(), dtype=float32)
# Test loss:  0.9286192
# Train accuracy:  0.7869247871700762
# Test accuracy:  0.7451234076433121
#
# Epoch: __ 49
# Train loss:  tf.Tensor(0.609551, shape=(), dtype=float32)
# Test loss:  0.90953714
# Train accuracy:  0.7931838429227233
# Test accuracy:  0.7448248407643312
#
# Epoch: __ 50
# Train loss:  tf.Tensor(0.6154975, shape=(), dtype=float32)
# Test loss:  0.9384274
# Train accuracy:  0.7930155794135284
# Test accuracy:  0.7366640127388535
#
# Epoch: __ 51
# Train loss:  tf.Tensor(0.60052437, shape=(), dtype=float32)
# Test loss:  0.8905037
# Train accuracy:  0.7987328033361951
# Test accuracy:  0.7597531847133758
#
# Epoch: __ 52
# Train loss:  tf.Tensor(0.59900653, shape=(), dtype=float32)
# Test loss:  0.87333614
# Train accuracy:  0.8073177857731297
# Test accuracy:  0.7751791401273885
#
# Epoch: __ 53
# Train loss:  tf.Tensor(0.58119184, shape=(), dtype=float32)
# Test loss:  0.8892041
# Train accuracy:  0.8225057105267323
# Test accuracy:  0.76453025477707
#
# Epoch: __ 54
# Train loss:  tf.Tensor(0.5823468, shape=(), dtype=float32)
# Test loss:  0.87162584
# Train accuracy:  0.8149296146377027
# Test accuracy:  0.7681130573248408
#
# Epoch: __ 55
# Train loss:  tf.Tensor(0.54949737, shape=(), dtype=float32)
# Test loss:  0.8887059
# Train accuracy:  0.8219743365810847
# Test accuracy:  0.7582603503184714
#
# Epoch: __ 56
# Train loss:  tf.Tensor(0.5315774, shape=(), dtype=float32)
# Test loss:  0.8414905
# Train accuracy:  0.830067661631334
# Test accuracy:  0.7788614649681529
#
# Epoch: __ 57
# Train loss:  tf.Tensor(0.5347193, shape=(), dtype=float32)
# Test loss:  0.87149125
# Train accuracy:  0.8242333009433718
# Test accuracy:  0.7736863057324841
#
# Epoch: __ 58
# Train loss:  tf.Tensor(0.53880006, shape=(), dtype=float32)
# Test loss:  0.8547428
# Train accuracy:  0.8201657017630755
# Test accuracy:  0.7673168789808917
#
# Epoch: __ 59
# Train loss:  tf.Tensor(0.5451452, shape=(), dtype=float32)
# Test loss:  0.8820482
# Train accuracy:  0.8118142977062706
# Test accuracy:  0.7732882165605095
#
# Epoch: __ 60
# Train loss:  tf.Tensor(0.51823145, shape=(), dtype=float32)
# Test loss:  0.87090063
# Train accuracy:  0.8206872642081208
# Test accuracy:  0.76671974522293
#
# Epoch: __ 61
# Train loss:  tf.Tensor(0.5155329, shape=(), dtype=float32)
# Test loss:  0.8455783
# Train accuracy:  0.8240719929406942
# Test accuracy:  0.7837380573248408
#
# Epoch: __ 62
# Train loss:  tf.Tensor(0.49978945, shape=(), dtype=float32)
# Test loss:  0.8709567
# Train accuracy:  0.8357943805429804
# Test accuracy:  0.7597531847133758
#
# Epoch: __ 63
# Train loss:  tf.Tensor(0.49847463, shape=(), dtype=float32)
# Test loss:  0.87072104
# Train accuracy:  0.8395440334123855
# Test accuracy:  0.7746815286624203
#
# Epoch: __ 64
# Train loss:  tf.Tensor(0.52486587, shape=(), dtype=float32)
# Test loss:  0.8469526
# Train accuracy:  0.8154466499486618
# Test accuracy:  0.7838375796178344
#
# Epoch: __ 65
# Train loss:  tf.Tensor(0.4894367, shape=(), dtype=float32)
# Test loss:  0.84081465
# Train accuracy:  0.8366068947885247
# Test accuracy:  0.777468152866242
#
# Epoch: __ 66
# Train loss:  tf.Tensor(0.47740376, shape=(), dtype=float32)
# Test loss:  0.8619923
# Train accuracy:  0.8450673237311113
# Test accuracy:  0.7865246815286624
#
# Epoch: __ 67
# Train loss:  tf.Tensor(0.51628363, shape=(), dtype=float32)
# Test loss:  0.8458254
# Train accuracy:  0.8416651076863748
# Test accuracy:  0.7788614649681529
#
# Epoch: __ 68
# Train loss:  tf.Tensor(0.49280858, shape=(), dtype=float32)
# Test loss:  0.8365014
# Train accuracy:  0.8431730485062803
# Test accuracy:  0.7734872611464968
#
# Epoch: __ 69
# Train loss:  tf.Tensor(0.46858928, shape=(), dtype=float32)
# Test loss:  0.8547054
# Train accuracy:  0.8405616096469746
# Test accuracy:  0.7789609872611465
#
# Epoch: __ 70
# Train loss:  tf.Tensor(0.43030632, shape=(), dtype=float32)
# Test loss:  0.83259964
# Train accuracy:  0.8612198056680519
# Test accuracy:  0.7744824840764332
#
# Epoch: __ 71
# Train loss:  tf.Tensor(0.45603138, shape=(), dtype=float32)
# Test loss:  0.81767625
# Train accuracy:  0.8446645601477867
# Test accuracy:  0.794984076433121
#
# Epoch: __ 72
# Train loss:  tf.Tensor(0.46529388, shape=(), dtype=float32)
# Test loss:  0.79756254
# Train accuracy:  0.8459248178525315
# Test accuracy:  0.7925955414012739
#
# Epoch: __ 73
# Train loss:  tf.Tensor(0.41576374, shape=(), dtype=float32)
# Test loss:  0.8070454
# Train accuracy:  0.8631859156180095
# Test accuracy:  0.7927945859872612
#
# Epoch: __ 74
# Train loss:  tf.Tensor(0.4638809, shape=(), dtype=float32)
# Test loss:  0.82070416
# Train accuracy:  0.8493057112505873
# Test accuracy:  0.7881170382165605
#
# Epoch: __ 75
# Train loss:  tf.Tensor(0.43794483, shape=(), dtype=float32)
# Test loss:  0.80866957
# Train accuracy:  0.8550432193345701
# Test accuracy:  0.793093152866242
#
# Epoch: __ 76
# Train loss:  tf.Tensor(0.44079754, shape=(), dtype=float32)
# Test loss:  0.8210451
# Train accuracy:  0.8504157750351974
# Test accuracy:  0.7829418789808917
#
# Epoch: __ 77
# Train loss:  tf.Tensor(0.4518749, shape=(), dtype=float32)
# Test loss:  0.8038048
# Train accuracy:  0.8545342733779001
# Test accuracy:  0.8053343949044586
#
# Epoch: __ 78
# Train loss:  tf.Tensor(0.43761253, shape=(), dtype=float32)
# Test loss:  0.83076525
# Train accuracy:  0.856436637465805
# Test accuracy:  0.7822452229299363
#
# Epoch: __ 79
# Train loss:  tf.Tensor(0.4113454, shape=(), dtype=float32)
# Test loss:  0.8108213
# Train accuracy:  0.859380591147854
# Test accuracy:  0.7962778662420382
#
# Epoch: __ 80
# Train loss:  tf.Tensor(0.4059592, shape=(), dtype=float32)
# Test loss:  0.8258397
# Train accuracy:  0.8693033710948448
# Test accuracy:  0.7916998407643312
#
# Epoch: __ 81
# Train loss:  tf.Tensor(0.41454133, shape=(), dtype=float32)
# Test loss:  0.7935208
# Train accuracy:  0.8637483695761858
# Test accuracy:  0.7923964968152867
#
# Epoch: __ 82
# Train loss:  tf.Tensor(0.38896692, shape=(), dtype=float32)
# Test loss:  0.7815493
# Train accuracy:  0.8760165647369519
# Test accuracy:  0.801453025477707
#
# Epoch: __ 83
# Train loss:  tf.Tensor(0.42361957, shape=(), dtype=float32)
# Test loss:  0.79909253
# Train accuracy:  0.8603301673315662
# Test accuracy:  0.8016520700636943
#
# Epoch: __ 84
# Train loss:  tf.Tensor(0.4230431, shape=(), dtype=float32)
# Test loss:  0.7880943
# Train accuracy:  0.8653316531162721
# Test accuracy:  0.7999601910828026
#
# Epoch: __ 85
# Train loss:  tf.Tensor(0.3964887, shape=(), dtype=float32)
# Test loss:  0.7967686
# Train accuracy:  0.8695411500327745
# Test accuracy:  0.7981687898089171
#
# Epoch: __ 86
# Train loss:  tf.Tensor(0.38712034, shape=(), dtype=float32)
# Test loss:  0.7791163
# Train accuracy:  0.8720996069171736
# Test accuracy:  0.8082205414012739
#
# Epoch: __ 87
# Train loss:  tf.Tensor(0.39893904, shape=(), dtype=float32)
# Test loss:  0.7878117
# Train accuracy:  0.8815280676258652
# Test accuracy:  0.7926950636942676
#
# Epoch: __ 88
# Train loss:  tf.Tensor(0.40611672, shape=(), dtype=float32)
# Test loss:  0.7888182
# Train accuracy:  0.8684197206846666
# Test accuracy:  0.798765923566879
#
# Epoch: __ 89
# Train loss:  tf.Tensor(0.38812393, shape=(), dtype=float32)
# Test loss:  0.75252736
# Train accuracy:  0.8673547073138403
# Test accuracy:  0.81140525477707
#
# Epoch: __ 90
# Train loss:  tf.Tensor(0.38197434, shape=(), dtype=float32)
# Test loss:  0.7817649
# Train accuracy:  0.8681323393863196
# Test accuracy:  0.803343949044586
#
# Epoch: __ 91
# Train loss:  tf.Tensor(0.39974254, shape=(), dtype=float32)
# Test loss:  0.7810776
# Train accuracy:  0.8692843708121794
# Test accuracy:  0.7876194267515924
#
# Epoch: __ 92
# Train loss:  tf.Tensor(0.40246964, shape=(), dtype=float32)
# Test loss:  0.8051804
# Train accuracy:  0.863789513444891
# Test accuracy:  0.7984673566878981
#
# Epoch: __ 93
# Train loss:  tf.Tensor(0.3790716, shape=(), dtype=float32)
# Test loss:  0.77915734
# Train accuracy:  0.872633184795633
# Test accuracy:  0.8029458598726115
#
# Epoch: __ 94
# Train loss:  tf.Tensor(0.38960633, shape=(), dtype=float32)
# Test loss:  0.76097137
# Train accuracy:  0.874597021831339
# Test accuracy:  0.806827229299363
#
# Epoch: __ 95
# Train loss:  tf.Tensor(0.3938551, shape=(), dtype=float32)
# Test loss:  0.82227224
# Train accuracy:  0.8716409446743176
# Test accuracy:  0.7923964968152867
#
# Epoch: __ 96
# Train loss:  tf.Tensor(0.3345268, shape=(), dtype=float32)
# Test loss:  0.7386767
# Train accuracy:  0.8896111216570555
# Test accuracy:  0.8131966560509554
#
# Epoch: __ 97
# Train loss:  tf.Tensor(0.34883937, shape=(), dtype=float32)
# Test loss:  0.7517472
# Train accuracy:  0.8891246327352444
# Test accuracy:  0.8073248407643312
#
# Epoch: __ 98
# Train loss:  tf.Tensor(0.34492323, shape=(), dtype=float32)
# Test loss:  0.77212834
# Train accuracy:  0.8947485680007148
# Test accuracy:  0.8071257961783439
#
# Epoch: __ 99
# Train loss:  tf.Tensor(0.34977934, shape=(), dtype=float32)
# Test loss:  0.7758136
# Train accuracy:  0.8946948932946476
# Test accuracy:  0.8024482484076433
#
# Epoch: __ 100
# Train loss:  tf.Tensor(0.3233995, shape=(), dtype=float32)
# Test loss:  0.75384194
# Train accuracy:  0.8969295660695787
# Test accuracy:  0.8120023885350318
#
# Epoch: __ 101
# Train loss:  tf.Tensor(0.38059336, shape=(), dtype=float32)
# Test loss:  0.76255417
# Train accuracy:  0.8831244136784078
# Test accuracy:  0.8102109872611465
#
# Epoch: __ 102
# Train loss:  tf.Tensor(0.3571619, shape=(), dtype=float32)
# Test loss:  0.75484794
# Train accuracy:  0.8896221877530316
# Test accuracy:  0.8117038216560509
#
# Epoch: __ 103
# Train loss:  tf.Tensor(0.34137362, shape=(), dtype=float32)
# Test loss:  0.74380136
# Train accuracy:  0.8876527257542706
# Test accuracy:  0.8202627388535032
#
# Epoch: __ 104
# Train loss:  tf.Tensor(0.3744053, shape=(), dtype=float32)
# Test loss:  0.7561757
# Train accuracy:  0.8748606963995365
# Test accuracy:  0.8045382165605095
#
# Epoch: __ 105
# Train loss:  tf.Tensor(0.37037224, shape=(), dtype=float32)
# Test loss:  0.7400929
# Train accuracy:  0.8832232555011819
# Test accuracy:  0.8122014331210191
#
# Epoch: __ 106
# Train loss:  tf.Tensor(0.33509853, shape=(), dtype=float32)
# Test loss:  0.7796619
# Train accuracy:  0.8961709954858068
# Test accuracy:  0.805234872611465
#
# Epoch: __ 107
# Train loss:  tf.Tensor(0.35062337, shape=(), dtype=float32)
# Test loss:  0.7560038
# Train accuracy:  0.8833767102634537
# Test accuracy:  0.8128980891719745
#
# Epoch: __ 108
# Train loss:  tf.Tensor(0.32793245, shape=(), dtype=float32)
# Test loss:  0.76408476
# Train accuracy:  0.8972782023748634
# Test accuracy:  0.8121019108280255
#
# Epoch: __ 109
# Train loss:  tf.Tensor(0.33871132, shape=(), dtype=float32)
# Test loss:  0.72743136
# Train accuracy:  0.8829175252015028
# Test accuracy:  0.8129976114649682
#
# Epoch: __ 110
# Train loss:  tf.Tensor(0.33325717, shape=(), dtype=float32)
# Test loss:  0.74090403
# Train accuracy:  0.8942609284367913
# Test accuracy:  0.8167794585987261
#
# Epoch: __ 111
# Train loss:  tf.Tensor(0.29529798, shape=(), dtype=float32)
# Test loss:  0.7403817
# Train accuracy:  0.907558410577248
# Test accuracy:  0.8123009554140127
#
# Epoch: __ 112
# Train loss:  tf.Tensor(0.31244975, shape=(), dtype=float32)
# Test loss:  0.7464148
# Train accuracy:  0.8983311787435608
# Test accuracy:  0.8102109872611465
#
# Epoch: __ 113
# Train loss:  tf.Tensor(0.35970393, shape=(), dtype=float32)
# Test loss:  0.7419281
# Train accuracy:  0.88016812047397
# Test accuracy:  0.8126990445859873
#
# Epoch: __ 114
# Train loss:  tf.Tensor(0.29938316, shape=(), dtype=float32)
# Test loss:  0.73499304
# Train accuracy:  0.909019212341054
# Test accuracy:  0.8179737261146497
#
# Epoch: __ 115
# Train loss:  tf.Tensor(0.30523723, shape=(), dtype=float32)
# Test loss:  0.72443193
# Train accuracy:  0.902052627830449
# Test accuracy:  0.8209593949044586
#
# Epoch: __ 116
# Train loss:  tf.Tensor(0.30189627, shape=(), dtype=float32)
# Test loss:  0.7460715
# Train accuracy:  0.8964580853223548
# Test accuracy:  0.8075238853503185
#
# Epoch: __ 117
# Train loss:  tf.Tensor(0.32375816, shape=(), dtype=float32)
# Test loss:  0.7256638
# Train accuracy:  0.8912919477963677
# Test accuracy:  0.8238455414012739
#
# Epoch: __ 118
# Train loss:  tf.Tensor(0.31160322, shape=(), dtype=float32)
# Test loss:  0.71924627
# Train accuracy:  0.8988775375448541
# Test accuracy:  0.8228503184713376
#
# Epoch: __ 119
# Train loss:  tf.Tensor(0.30284148, shape=(), dtype=float32)
# Test loss:  0.7171751
# Train accuracy:  0.9024084722259217
# Test accuracy:  0.8217555732484076
#
# Epoch: __ 120
# Train loss:  tf.Tensor(0.33485693, shape=(), dtype=float32)
# Test loss:  0.723634
# Train accuracy:  0.8908749734298209
# Test accuracy:  0.817078025477707
#
# Epoch: __ 121
# Train loss:  tf.Tensor(0.32591525, shape=(), dtype=float32)
# Test loss:  0.7349376
# Train accuracy:  0.894097059726255
# Test accuracy:  0.8118033439490446
#
# Epoch: __ 122
# Train loss:  tf.Tensor(0.2738117, shape=(), dtype=float32)
# Test loss:  0.7271626
# Train accuracy:  0.9139815389342368
# Test accuracy:  0.8091162420382165
#
# Epoch: __ 123
# Train loss:  tf.Tensor(0.30725527, shape=(), dtype=float32)
# Test loss:  0.74106115
# Train accuracy:  0.8987780305220185
# Test accuracy:  0.808718152866242
#
# Epoch: __ 124
# Train loss:  tf.Tensor(0.2880572, shape=(), dtype=float32)
# Test loss:  0.7047502
# Train accuracy:  0.9042616806748944
# Test accuracy:  0.8165804140127388
#
# Epoch: __ 125
# Train loss:  tf.Tensor(0.31303638, shape=(), dtype=float32)
# Test loss:  0.7459477
# Train accuracy:  0.9060304818951688
# Test accuracy:  0.8130971337579618
#
# Epoch: __ 126
# Train loss:  tf.Tensor(0.28202415, shape=(), dtype=float32)
# Test loss:  0.7227136
# Train accuracy:  0.905769597187887
# Test accuracy:  0.817078025477707
#
# Epoch: __ 127
# Train loss:  tf.Tensor(0.3214262, shape=(), dtype=float32)
# Test loss:  0.7378984
# Train accuracy:  0.8910226440419586
# Test accuracy:  0.8123009554140127
#
# Epoch: __ 128
# Train loss:  tf.Tensor(0.29132685, shape=(), dtype=float32)
# Test loss:  0.75295836
# Train accuracy:  0.9062917386704921
# Test accuracy:  0.7965764331210191
#
# Epoch: __ 129
# Train loss:  tf.Tensor(0.3208054, shape=(), dtype=float32)
# Test loss:  0.7270257
# Train accuracy:  0.8994455791479482
# Test accuracy:  0.8107085987261147
#
# Epoch: __ 130
# Train loss:  tf.Tensor(0.29082, shape=(), dtype=float32)
# Test loss:  0.6977635
# Train accuracy:  0.9077595734697292
# Test accuracy:  0.8148885350318471
#
# Epoch: __ 131
# Train loss:  tf.Tensor(0.27634338, shape=(), dtype=float32)
# Test loss:  0.7209666
# Train accuracy:  0.9107194242840183
# Test accuracy:  0.8157842356687898
#
# Epoch: __ 132
# Train loss:  tf.Tensor(0.27945197, shape=(), dtype=float32)
# Test loss:  0.72521544
# Train accuracy:  0.9115560405800082
# Test accuracy:  0.8217555732484076
#
# Epoch: __ 133
# Train loss:  tf.Tensor(0.26794258, shape=(), dtype=float32)
# Test loss:  0.7377795
# Train accuracy:  0.9109415990554397
# Test accuracy:  0.798765923566879
#
# Epoch: __ 134
# Train loss:  tf.Tensor(0.293243, shape=(), dtype=float32)
# Test loss:  0.7223774
# Train accuracy:  0.9009919625806985
# Test accuracy:  0.8182722929936306
#
# Epoch: __ 135
# Train loss:  tf.Tensor(0.2792501, shape=(), dtype=float32)
# Test loss:  0.7126192
# Train accuracy:  0.9163788927935558
# Test accuracy:  0.8089171974522293
#
# Epoch: __ 136
# Train loss:  tf.Tensor(0.27848494, shape=(), dtype=float32)
# Test loss:  0.7302824
# Train accuracy:  0.9127902490012709
# Test accuracy:  0.8163813694267515
#
# Epoch: __ 137
# Train loss:  tf.Tensor(0.29683265, shape=(), dtype=float32)
# Test loss:  0.69820994
# Train accuracy:  0.9037485661793692
# Test accuracy:  0.8232484076433121
#
# Epoch: __ 138
# Train loss:  tf.Tensor(0.255947, shape=(), dtype=float32)
# Test loss:  0.71309304
# Train accuracy:  0.9173380901599493
# Test accuracy:  0.8191679936305732
#
# Epoch: __ 139
# Train loss:  tf.Tensor(0.2560418, shape=(), dtype=float32)
# Test loss:  0.72603077
# Train accuracy:  0.9207281076118621
# Test accuracy:  0.804140127388535
#
# CPU times: user 30min 36s, sys: 1min 9s, total: 31min 45s
# Wall time: 50min 35s

# %% [markdown]
# ## Plotting accuracy and loss for training and test data.

# %%
fig, ax = plt.subplots(2,1,sharex=True,figsize=(15,15))
ax[0].plot(train_losses,label="Training")
ax[0].plot(test_losses,label="Test")

ax[1].plot(train_accuracies,label="Training")
ax[1].plot(test_accuracies,label="Test")

fontsize=24
ax[0].set_ylabel("Loss",fontsize=fontsize)
ax[1].set_ylabel("Accuracy",fontsize=fontsize)
ax[1].set_xlabel("Epochs",fontsize=fontsize)
ax[1].axhline(0.85,xmax=num_epochs,c='g',ls='--')
ax[0].legend()
ax[1].legend()
plt.show()

# %% [markdown]
# ## Check latest test accuracy

# %%
test_accuracies[-1]
# Out:
# 0.804140127388535
