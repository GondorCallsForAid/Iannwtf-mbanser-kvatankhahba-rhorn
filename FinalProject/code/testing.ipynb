# %% [markdown]
# ## Libraries

# %%
import moviepy.editor as mp
from moviepy.audio.AudioClip import AudioArrayClip
# python -m pip install git+https://github.com/nficano/pytube
from pytube import YouTube 
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-d8ca8fab29a5> in <module>
# ----> 1 import moviepy.editor as mp
#       2 from moviepy.audio.AudioClip import AudioArrayClip
#       3 # python -m pip install git+https://github.com/nficano/pytube
#       4 from pytube import YouTube
#       5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'moviepy'

# %% [markdown]
# ## Testing

# %%
clip = mp.VideoFileClip("../data/Soviet_Tank_Meme.mp4")
audio = clip.audio.to_soundarray()
plt.plot(audio[100000:190000])
# Out:
# [<matplotlib.lines.Line2D at 0x7fba79b14450>,
#  <matplotlib.lines.Line2D at 0x7fba7b4cf210>]

# %%
audio_1 = audio[10000:100000]
audio_2 = audio[100000:190000]
combined = audio_1 + audio_2
plt.plot(combined)
# Out:
# [<matplotlib.lines.Line2D at 0x7f7f8c347750>,
#  <matplotlib.lines.Line2D at 0x7f7f8c33b510>]

# %%
audio_stereo = AudioArrayClip(combined, fps=44100)
audio_stereo.write_audiofile('../data/stereo.mp3')
# Out:
# MoviePy - Writing audio in ../data/stereo.mp3
# MoviePy - Done.

# %%
len_in_sec = clip.audio.duration
len_in_samples = audio.shape[0]

print('{:20s} {:16f}'.format("length in sec:", len_in_sec))
print('{:20s} {:16f}'.format("length in samples:", len_in_samples), "\n")
print('{:20s} {:16f}'.format("samples per second:", len_in_samples/len_in_sec))
# Out:
# length in sec:              11.340000
# length in samples:      500094.000000
#
# samples per second:      44100.000000

# %%
clip.audio.preview()

# %% [markdown]
# ## Fetch videos from youtube

# %%
url = "https://www.youtube.com/watch?v=m_Eb1OKTrig"
video = YouTube(url)
print(video.check_availability())
# Out:
# None

# %%
filter_words = ["Hi", "d", "a"]
text = "L"

any([w in text for w in filter_words])
# Out:
# False

# %%
# check available streams
video.streams.filter(abr="96kbps")
# Out:
# [<Stream: itag="18" mime_type="video/mp4" res="360p" fps="24fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">]

# %%
# filter streams
video.streams.filter(res="240p", file_extension="mp4")
# Out:
# [<Stream: itag="133" mime_type="video/mp4" res="240p" fps="24fps" vcodec="avc1.4d400c" progressive="False" type="video">, <Stream: itag="395" mime_type="video/mp4" res="240p" fps="24fps" vcodec="av01.0.00M.08" progressive="False" type="video">]

# %%
# download video
stream = video.streams.filter(res="240p", file_extension="mp4")[0]
stream.download(output_path = "../data", filename = "wave_clip")
# Out:
# '/Users/RobinHorn/Documents/UNI/S5/Iannwtf/FinalProject/code/../data/wave_clip.mp4'

# %%
s = video.streams.filter(abr="96kbps")[0]
s.download(output_path = "../data", filename = "wave_clip_2")
# Out:
# '/Users/RobinHorn/Documents/UNI/S5/Iannwtf/FinalProject/code/../data/wave_clip_2.mp4'

# %%
clip = mp.VideoFileClip("../data/wave_clip_2.mp4")
audio = clip.audio.to_soundarray()
plt.plot(audio)
# Out:
# [<matplotlib.lines.Line2D at 0x7fba7b226d10>,
#  <matplotlib.lines.Line2D at 0x7fba7af61ad0>]

# %%
len_in_sec = clip.audio.duration
len_in_samples = audio.shape[0]

print('{:20s} {:16f}'.format("length in sec:", len_in_sec))
print('{:20s} {:16f}'.format("length in samples:", len_in_samples), "\n")
print('{:20s} {:16f}'.format("samples per second:", len_in_samples/len_in_sec))
# Out:
# length in sec:               9.430000
# length in samples:      415863.000000
#
# samples per second:      44100.000000

# %%
# import the os module
import os

# detect the current working directory and print it
path = os.getcwd()
print ("The current working directory is %s" % path)
# Out:
# The current working directory is /Users/RobinHorn/Documents/UNI/S5/Iannwtf/FinalProject/code
